# %%
print("Hello World")

# %% [markdown]
# **Step 1 Data Exploration & Leading**

# %%
# importing dependencies

import pandas as pd

#mysql toolkit
import pymysql #this will work as adapter
from sqlalchemy import create_engine

#psql
import psycopg2

# %%
print(pd.__version__)

# %%
df = pd.read_csv('Walmart.csv', encoding_errors='ignore')

df.shape
# Out:
# (10051, 11)

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
#all duplicates
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()

# %%
df.shape

# %%
df.isnull().sum()

# %%
#droping all roes with missiing records
df.dropna(inplace=True)

# %%
df.isnull().sum()

# %%
df.dtypes

# %%
df['unit_price'].astype(float)

# %%
df['unit_price'] = df['unit_price'].str.replace('$', ' ').astype(float)

df.head()

# %%
df.info()

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='str')

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='str')

# %%
df['total'] = df['unit_price'] * df['quantity']
df.head()

# %%
# mysql
# host = localhost
# port = 3306
# user = Uday
# password = 'Uday@1230

# psql(me not installed postgrage sql!)
# host = localhost
# port = 5432
# user = Uday
# password = 'Uday@1230'

# %%
df.shape

# %%
df.to_csv('walmart_clean_data.csv', index=False)

# %%
engine_mysql = create_engine("mysql+pymysql://root:uday123@localhost:3306/walmart_db")

# %%
df.to_sql(name='walmart', con=engine_mysql, if_exists='append', index=False)
# Out:
# 10051
